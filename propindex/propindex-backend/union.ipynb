# %%
import pandas as pd
cabaprop = pd.read_json("datos_geolocalizados_cabaprop.json", orient="records")
remax = pd.read_json("datos_geolocalizados_remax.json", orient="records")
mudafy = pd.read_json("datos_geolocalizados_mudafy.json", orient="records")
mudafy['Publicada_en']="Mudafy"
df= pd.concat([cabaprop, remax,mudafy], ignore_index=True)
df = df[['Direccion', 'Precio', 'Ambientes', 'Baños', 'Total', 'Cubierta', 'Antigüedad', 'Publicada_en', 'Categoria_antigüedad', 'lat', 'lon']]

# %%
remax
# Out:
#                                                  Titulo  \
# 0     Emprendimiento en construcción entre 1 y 3 amb...
# 1     Emprendimiento en terminado entre 1 y 2 ambien...
# 2     Emprendimiento en pre venta entre 1 y 2 ambien...
# 3     Emprendimiento en pre venta entre 1 y 4 ambien...
# 4     Emprendimiento en construcción entre 2 y 4 amb...
# ...                                                 ...
# 1309  Departamento en venta 4 ambientes en Avenida G...
# 1310  Departamento en venta 1 ambiente en Carranza 1...
# 1311  Departamento en venta 2 ambientes en Güemes 45...
# 1312  Departamento en venta 1 ambiente en Niceto Veg...
# 1313  Departamento en venta 1 ambiente en Güemes 450...
#
#                                               Operacion  \
# 0     Mirá este emprendimiento en RE/MAX: UrbanHaus ...
# 1     Mirá este emprendimiento en RE/MAX: Departamen...
# 2     Mirá este emprendimiento en RE/MAX: ¡Descubre ...
# 3     Mirá este emprendimiento en RE/MAX: Cacique De...
# ...

# %%
mudafy
# Out:
#                                                  Titulo  \
# 0     Departamento en Venta en 11 De Septiembre De 1...
# 1     Departamento en Venta en 3 DE FEBRERO al 2100,...
# 2     Departamento en Venta en 3 DE FEBRERO al 2100,...
# 3     Departamento en Venta en Acevedo 500, Villa Cr...
# 4     Departamento en Venta en Acevedo 500, Villa Cr...
# ...                                                 ...
# 1136      Departamento en Venta en Zapata 200, Belgrano
# 1137    Departamento en Venta en Zapata 200, Colegiales
# 1138       Departamento en Venta en Zapata 300, Palermo
# 1139    Departamento en Venta en ZAPATA al 300, Palermo
# 1140  Departamento en Venta en Zapiola 1000, Colegiales
#
#                                               Operacion  \
# 0     ¡Departamento en Palermo en Venta! Conocé esta...
# 1     ¡Departamento en Belgrano en Venta! Conocé est...
# 2     ¡Departamento en Belgrano en Venta! Conocé est...
# 3     ¡Departamento en Villa Crespo en Venta! Conocé...
# ...

# %%
df
# Out:
#           Direccion    Precio  Ambientes  Baños  Total  Cubierta  Antigüedad  \
# 0     Lafinur  3000  120000.0        1.0    1.0   33.0      33.0        15.0
# 1      CHARCAS 3400  430000.0        3.0    3.0  132.0     124.0         NaN
# 2     HUMBOLDT 1800  160000.0        2.0    1.0   78.0      70.0         NaN
# 3        ARAOZ 1200  140400.0        2.0    1.0   41.0      37.0         NaN
# 4     Cabrera  5100  112000.0        1.0    1.0   28.0      24.0         1.0
# ...             ...       ...        ...    ...    ...       ...         ...
# 3878     Zapata 200     275.2        3.0    1.0   76.0      65.0         0.0
# 3879     Zapata 200     271.0        3.0    1.0   89.0      65.0         0.0
# 3880     Zapata 300      89.9        1.0    1.0   21.0      21.0         1.0
# 3881     ZAPATA 300     120.0        2.0    1.0   55.0      47.0         0.0
# 3882   Zapiola 1000      85.0        2.0    1.0   40.0      40.0         5.0
#
# ...

# %%
remax = pd.read_json("datos_geolocalizados_remax.json", orient="records")

# %%
mudafy = mudafy[['Direccion', 'Precio', 'Ambientes', 'Baños', 'Total', 'Cubierta', 'Antigüedad', 'Publicada_en', 'Categoria_antigüedad', 'lat', 'lon']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mudafy = mudafy[['Direccion', 'Precio', 'Ambientes', 'Baños', 'Total', 'Cubierta', 'Antigüedad', 'Publicada_en', 'Categoria_antigüedad', 'lat', 'lon']]
#
# File c:\Users\abelf\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\abelf\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
remax
# Out:
#                                     Direccion   Precio  Ambientes  Baños  \
# 0                         Cordoba 4027 (1188)   72.501          3      2
# 1                       Santa Fe 5268 (C1425)   65.875          2      1
# 2                        Córdoba 4309 (C1414)   82.000          2      1
# 3     Soldado de la Independencia 704 (C1426)   83.000          4      3
# 4                           Cabildo 20 (1425)   62.900          4      2
# ...                                       ...      ...        ...    ...
# 1309                     Gener Las Heras 3800  379.000          4      3
# 1310                            Carranza 1400  117.000          1      1
# 1311                              Güemes 4500  180.000          2      1
# 1312                         Niceto Vega 5100   98.000          1      1
# 1313                              Güemes 4500  115.000          1      1
#
#        Total  Cubierta  Antigüedad Publicada_en  Categoria_antigüedad  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Direccion             3882 non-null   object
#  1   Precio                3863 non-null   float64
#  2   Ambientes             3698 non-null   float64
#  3   Baños                 3704 non-null   float64
#  4   Total                 3882 non-null   float64
#  5   Cubierta              3790 non-null   float64
#  6   Antigüedad            3615 non-null   float64
#  7   Publicada_en          3883 non-null   object
#  8   Categoria_antigüedad  3615 non-null   float64
#  9   lat                   3485 non-null   float64
#  10  lon                   3485 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 333.8+ KB

# %%
df_nuevo = pd.concat([cabaprop, remax], ignore_index=True)

# %%
df_nuevo = df_nuevo[['Direccion', 'Precio', 'Ambientes', 'Baños', 'Total', 'Cubierta', 'Antigüedad', 'Publicada_en', 'Categoria_antigüedad', 'lat', 'lon']]

# %%
df_nuevo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2742 entries, 0 to 2741
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Direccion             2741 non-null   object
#  1   Precio                2722 non-null   float64
#  2   Ambientes             2557 non-null   float64
#  3   Baños                 2563 non-null   float64
#  4   Total                 2741 non-null   float64
#  5   Cubierta              2649 non-null   float64
#  6   Antigüedad            2474 non-null   float64
#  7   Publicada_en          2742 non-null   object
#  8   Categoria_antigüedad  2474 non-null   float64
#  9   lat                   2344 non-null   float64
#  10  lon                   2344 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 235.8+ KB
